# %%
import numpy as np 
import pandas as pd 
import scipy as sp 

import matplotlib.pyplot as plt 
import seaborn as sns

# %matplotlib inline

# %%
from scipy.stats import binom

# %%
N = 10000
x = np.arange(N+1)
y = tuple(binom.cdf(i, p=0.3, n=N) for i in x)

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('probabilidad continua')
# Out:
# Text(0.5, 1.0, 'probabilidad continua')

# %%
mean, var, skew, kurt =  sp.stats.norm.stats(moments = 'mvsk')
mean, var
# Out:
# (array(0.), array(1.))
