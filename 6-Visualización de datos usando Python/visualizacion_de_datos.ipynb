# %%
import numpy as np 
import pandas as pd 
import scipy as sp 

import matplotlib.pyplot as plt 
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("../data/bicicletas-compartidas.csv")

# %% [markdown]
# Categoricas

# %%
df.columns
# Out:
# Index(['fecha', 'bicis-compartidas', 'temp-obs', 'sens-temp', 'hum', 'viento',
#        'codigo-clima', 'festivo', 'findesemana', 'cuartil-ano'],
#       dtype='object')

# %%
y = df ['cuartil-ano'].apply(lambda x: f'cuartil-{x}')

# %%
fig, ax = plt.subplots()
ax.bar(y.value_counts().index,y.value_counts())
ax.set_xlabel('Cuatiles del año')
ax.set_ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
fig, ax = plt.subplots()
ax.bar(y.value_counts().index,y.value_counts())
ax.set_xlabel('Cuatiles del año')
ax.set_ylabel('Frecuencia')
ax.patches[2].set_facecolor('red')

# %%
fig, ax = plt.subplots()
ax.pie(y.value_counts(), labels= y.value_counts().index)
ax.set_title('Diagrama de pie')
# Out:
# Text(0.5, 1.0, 'Diagrama de pie')

# %% [markdown]
# Numéricas

# %%
y = df['viento']

# %%
fig, ax = plt.subplots()
ax.hist(y, bins = 30)
ax.set_xlabel('Viento')
ax.set_ylabel('Frecuecias')
plt.axvline(np.mean(y), c='r', linestyle = '--', label = 'Promedio')
plt.axvline(np.mean(y) + np.std(y), c='k', linestyle = '--', label = '1+Desviación')
plt.axvline(np.mean(y) - np.std(y), c='k', linestyle = '--', label = '1-Desviación')
ax.legend()
